# %% [markdown]
# # Лабораторна робота № 7

# %% [markdown]
# ## Тема. Структури даних дерево, купа, геш-таблиця

# %% [markdown]
# ## Мета: засвоїти основні функції та алгоритми роботи з деревами та купою засобами Python..

# %% [markdown]
# ### Виконав Гладкий Іван

# %% [markdown]
# # Хід роботи

# %% [markdown]
# ## 1)  Створити бінарне дерево згідно з варіантом, виданим викладачем. Написати процедуру видалення заданої гілки дерева. (Я не знайшов де взяти варіант за яким створювати бінарне дерево). Оцінити асимптотичну складність (в середньому і в найгіршому випадку) процедур search, insert і delete роботи з деревом...

# %% [markdown]
# <img src="image\lab6.1.png" alt="щось">

# %% [markdown]
# ### Search: Середня складність: O(log n). Найгірша складність: O(n) (у збалансованого дерева O(log n)).
# ### Insert: Середня складність: O(log n). Найгірша складність: O(n) (у збалансованого дерева O(log n)).
# ### Delete: Середня складність: O(log n). Найгірша складність: O(n) (у збалансованого дерева O(log n)).ті O(n))

# %% [markdown]
# ## 2) Написати процедуру генерації купи з будь-якого рандомного масива. Додати до нього елемент, який дорівнює вашому порядковому номеру у списку групи. Вилучити максимальний елемент з купи. Оцінити асимптотичну складність (у середньому і в найгіршому випадку) процедур search, insert і delete роботи з купою.

# %% [markdown]
# <img src="image\lab7.2.png" alt="щось">

# %% [markdown]
# ### Search: Середня складність: O(n). Найгірша складність: O(n).
# ### Insert: Середня складність: O(log n). Найгірша складність: O(log n).
# ### Delete: Середня складність: O(log n). Найгірша складність: O(log n).

# %% [markdown]
# ## 3) Вивчіть самостійно різні методи розв’язання колізій. Реалізуйте геш-таблицю з ланцюжковим гешуванням. Проведіть тестування геш-таблиці з різними типами даних (цілі числа, рядки, списки, словники, об’єкти): перевірити працездатність геш-таблиці з різними типами даних. Виміряти час виконання основних операцій (пошук, вставка, видалення) для різних типів даних. Порівняти результати для різних типів даних. даних.

# %% [markdown]
# <img src="image\lab7.3.png" alt="щось">

# %% [markdown]
# ## Відповіді на запитання

# %% [markdown]
# ### 1) Бінарне дерево - це загальне поняття про дерево з двома нащадками на кожному вузлі, тоді як бінарне дерево пошуку є одним з типів бінарного дерева, в якому кожен вузол має ключ.

# %% [markdown]
# ### 2) У бінарному дереві кожен вузол може мати не більше двох дочірніх вузлів. Ключі можуть бути будь-які, не обов'язково впорядковані. Одна з відмінних операцій - пошук. У бінарній купі батьківський вузол має значення, яке менше або рівне значенню кожного з його дочірніх вузлів. Одна з відмінних операцій - отримання min max значення.значення.

# %% [markdown]
# ### 3) Бінарне дерево, бінарне дерево пошуку, бінарна купа. Переваги та недоліки по суті описані в їх порівнянні.

# %% [markdown]
# ### 4) Алгоритм маршрутизації, побудова рішень, класифікація, рекурсивний пошук, кластеризація, оптимізація, визначення відстаней між точками, мінімізація витраченого часу на задачу та визначення відстаней.між точками:

# %% [markdown]
# ### 5) Зазвичай купа має форму бінарного дерева, але фактично зберігається в масиві.
# ### Додавання - додати новий елемент у кінець купи. Порівняти значення нового елемента з його батьківським елементом. Якщо новий елемент більший або менший за його батьківський елемент, поміняти їх місцями. Повторювати доки властивість купи не буде відновлена.
# ### Вилучення - вилучити перший елемент. Перенести останній елемент  на місце кореня. Порівняти нове кореневе значення з його дочірніми елементами. Якщо нове кореневе значення менше  або більше  за один із його дочірніх елементів, поміняти їх місцями. Повторювати доки властивість купи не буде відновлена.

# %% [markdown]
# ### 6) Сортування масиву за допомогою купи, знаходження "i-ого" min max елемента в масиві.

# %% [markdown]
# ### 7) Перетворення ключа (даних) у відносно унікальне число.
